# ####   These items can be frequently bought rolls/buns, condensed milk, whole milk, other vegetables
# ####   These items can be frequently bought cake bar, whole milk
# ####   These items can be frequently bought soda, frozen dessert, whole milk
# ####   These items can be frequently bought mustard, whole milk
# ####   These items can be frequently bought salt, whole milk
# ####   These items can be frequently bought pet care, other vegetables, rolls/buns
# ####   These items can be frequently bought canned vegetables, whole milk
# ####   These items can be frequently bought dog food, whole milk
# add Codeadd Markdown

# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/groceries-dataset-for-market-basket-analysismba/Groceries data.csv
# /kaggle/input/groceries-dataset-for-market-basket-analysismba/basket.csv

# %%
import numpy as np 
import pandas as pd 
import collections
from itertools import permutations
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import parallel_coordinates
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff
import networkx as nx
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly
import igraph as ig
from plotly.graph_objs import *

# %%
df = pd.read_csv("../input/groceries-dataset-for-market-basket-analysismba/Groceries data.csv")
df
# Out:
#        Member_number        Date        itemDescription  year  month  day  \
# 0               1808  2015-07-21         tropical fruit  2015      7   21
# 1               2552  2015-05-01             whole milk  2015      5    1
# 2               2300  2015-09-19              pip fruit  2015      9   19
# 3               1187  2015-12-12       other vegetables  2015     12   12
# 4               3037  2015-01-02             whole milk  2015      1    2
# ...              ...         ...                    ...   ...    ...  ...
# 38760           4471  2014-08-10          sliced cheese  2014      8   10
# 38761           2022  2014-02-23                  candy  2014      2   23
# 38762           1097  2014-04-16               cake bar  2014      4   16
# 38763           1510  2014-03-12  fruit/vegetable juice  2014      3   12
# 38764           1521  2014-12-26               cat food  2014     12   26
#
#        day_of_week
# 0                1
# 1                4
# ...

# %%
# review the unique values in the member ID and item columns
print(len(df['Member_number'].unique()))
print(len(df['itemDescription'].unique()))
# Out:
# 3898
# 167

# %%
# review the value counts
freq_items = df['itemDescription'].value_counts()
item=freq_items.reset_index()
top_itm=item['index'].head(35).to_list()
print(top_itm)
freq_items.head(10)
# Out:
# ['whole milk', 'other vegetables', 'rolls/buns', 'soda', 'yogurt', 'root vegetables', 'tropical fruit', 'bottled water', 'sausage', 'citrus fruit', 'pastry', 'pip fruit', 'shopping bags', 'canned beer', 'bottled beer', 'whipped/sour cream', 'newspapers', 'frankfurter', 'brown bread', 'pork', 'domestic eggs', 'butter', 'fruit/vegetable juice', 'beef', 'curd', 'margarine', 'coffee', 'frozen vegetables', 'chicken', 'white bread', 'cream cheese ', 'chocolate', 'dessert', 'napkins', 'hamburger meat']
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: itemDescription, dtype: int64

# %%
# list items by member IDs
user_id = df['Member_number'].unique()
items = [list(df.loc[df['Member_number'] == id, 'itemDescription']) for id in user_id]
print(items[0])
# Out:
# ['tropical fruit', 'long life bakery product', 'meat', 'sugar', 'rolls/buns', 'semi-finished bread', 'whole milk', 'citrus fruit', 'candy', 'napkins']

# %%
# create a item matrix
TE = TransactionEncoder()
TE.fit(items)
item_transformed = TE.transform(items)
item_matrix = pd.DataFrame(item_transformed, columns = TE.columns_)
item_matrix.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False  False    False
# 2           False  False          False             False  False    False
# 3           False  False          False             False  False    False
# 4           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# ...

# %%
# get the support value by Apriori algorithm
freq_items = apriori(item_matrix, min_support=0.01, use_colnames=True, max_len=2)
freq_items.sort_values(by = "support", ascending = False)
# Out:
#        support                             itemsets
# 113   0.458184                         (whole milk)
# 69    0.376603                   (other vegetables)
# 84    0.349666                         (rolls/buns)
# 94    0.313494                               (soda)
# 114   0.282966                             (yogurt)
# ...        ...                                  ...
# 414   0.010005           (frankfurter, butter milk)
# 705   0.010005               (whole milk, dog food)
# 882   0.010005       (newspapers, hygiene articles)
# 1106  0.010005                      (pork, waffles)
# 790   0.010005  (frozen vegetables, hamburger meat)
#
# [1242 rows x 2 columns]

# %%
# get the support value by Apriori algorithm
freq_items = apriori(item_matrix, min_support=0.01, use_colnames=True, max_len=2)
freq_items.sort_values(by = "support", ascending = False)
# Out:
#        support                             itemsets
# 113   0.458184                         (whole milk)
# 69    0.376603                   (other vegetables)
# 84    0.349666                         (rolls/buns)
# 94    0.313494                               (soda)
# 114   0.282966                             (yogurt)
# ...        ...                                  ...
# 414   0.010005           (frankfurter, butter milk)
# 705   0.010005               (whole milk, dog food)
# 882   0.010005       (newspapers, hygiene articles)
# 1106  0.010005                      (pork, waffles)
# 790   0.010005  (frozen vegetables, hamburger meat)
#
# [1242 rows x 2 columns]

# %%
# create a datafram with product support, confidence , and lift values
rules = association_rules(freq_items, metric = "confidence", min_threshold = 0)
rules
# Out:
#          antecedents      consequents  antecedent support  consequent support  \
# 0         (UHT-milk)           (beef)            0.078502            0.119548
# 1             (beef)       (UHT-milk)            0.119548            0.078502
# 2     (bottled beer)       (UHT-milk)            0.158799            0.078502
# 3         (UHT-milk)   (bottled beer)            0.078502            0.158799
# 4         (UHT-milk)  (bottled water)            0.078502            0.213699
# ...              ...              ...                 ...                 ...
# 2247    (white wine)     (whole milk)            0.044125            0.458184
# 2248        (yogurt)     (white wine)            0.282966            0.044125
# 2249    (white wine)         (yogurt)            0.044125            0.282966
# 2250    (whole milk)         (yogurt)            0.458184            0.282966
# 2251        (yogurt)     (whole milk)            0.282966            0.458184
#
# ...

# %%
# get the support value by Apriori algorithm
freq_items = apriori(item_matrix, min_support=0.01, use_colnames=True, max_len=5)
freq_items.sort_values(by = "support", ascending = False)
# Out:
#        support                                   itemsets
# 113   0.458184                               (whole milk)
# 69    0.376603                         (other vegetables)
# 84    0.349666                               (rolls/buns)
# 94    0.313494                                     (soda)
# 114   0.282966                                   (yogurt)
# ...        ...                                        ...
# 2269  0.010005           (whole milk, ice cream, sausage)
# 2266  0.010005  (ice cream, rolls/buns, other vegetables)
# 2263  0.010005      (whole milk, herbs, other vegetables)
# 956   0.010005                    (pork, misc. beverages)
# 2293  0.010005    (margarine, tropical fruit, rolls/buns)
#
# [3016 rows x 2 columns]

# %%
def zhangs_rule(rules):
    rule_support = rules['support'].copy()
    rule_ante = rules['antecedent support'].copy()
    rule_conseq = rules['consequent support'].copy()
    num = rule_support - (rule_ante * rule_conseq)
    denom = np.max((rule_support * (1 - rule_ante).values, 
                          rule_ante * (rule_conseq - rule_support).values), axis = 0)
    return num / denom

rules_zhangs_list = zhangs_rule(rules)
rules = rules.assign(zhang = rules_zhangs_list)
rules.head()
# Out:
#       antecedents      consequents  antecedent support  consequent support  \
# 0      (UHT-milk)           (beef)            0.078502            0.119548
# 1          (beef)       (UHT-milk)            0.119548            0.078502
# 2  (bottled beer)       (UHT-milk)            0.158799            0.078502
# 3      (UHT-milk)   (bottled beer)            0.078502            0.158799
# 4      (UHT-milk)  (bottled water)            0.078502            0.213699
#
#     support  confidence      lift  leverage  conviction     zhang
# 0  0.010518    0.133987  1.120775  0.001133    1.016672  0.116940
# 1  0.010518    0.087983  1.120775  0.001133    1.010396  0.122392
# 2  0.014879    0.093700  1.193597  0.002413    1.016769  0.192815
# 3  0.014879    0.189542  1.193597  0.002413    1.037933  0.176014
# 4  0.021293    0.271242  1.269268  0.004517    1.078960  0.230217

# %%
rules_eda= rules
rules_eda['antecedents'] = rules['antecedents'].apply(lambda a: ', '.join(list(a)))
rules_eda['consequents'] = rules['consequents'].apply(lambda a: ', '.join(list(a)))


rules_eda.head()
# Out:
#     antecedents    consequents  antecedent support  consequent support  \
# 0      UHT-milk           beef            0.078502            0.119548
# 1          beef       UHT-milk            0.119548            0.078502
# 2  bottled beer       UHT-milk            0.158799            0.078502
# 3      UHT-milk   bottled beer            0.078502            0.158799
# 4      UHT-milk  bottled water            0.078502            0.213699
#
#     support  confidence      lift  leverage  conviction     zhang
# 0  0.010518    0.133987  1.120775  0.001133    1.016672  0.116940
# 1  0.010518    0.087983  1.120775  0.001133    1.010396  0.122392
# 2  0.014879    0.093700  1.193597  0.002413    1.016769  0.192815
# 3  0.014879    0.189542  1.193597  0.002413    1.037933  0.176014
# 4  0.021293    0.271242  1.269268  0.004517    1.078960  0.230217

# %%
rules1=rules_eda
rules1['scorelftlvg']=(rules1['lift']*0.5 +rules1['leverage']*0.5)*100
rules1['scoreconcnf']=(rules1['confidence']*0.5 +rules1['conviction']*0.5)*100
rules1=rules1.sort_values(['scorelftlvg', 'scoreconcnf'], ascending=False)
rules1
# Out:
#         antecedents    consequents  antecedent support  consequent support  \
# 229       beverages    white bread            0.062083            0.088763
# 228     white bread      beverages            0.088763            0.062083
# 829         waffles        chicken            0.069010            0.100564
# 828         chicken        waffles            0.100564            0.069010
# 1749  specialty bar     newspapers            0.052591            0.139815
# ...             ...            ...                 ...                 ...
# 1001           pork         coffee            0.132376            0.114931
# 1123        dessert  domestic eggs            0.086455            0.133145
# 1122  domestic eggs        dessert            0.133145            0.086455
# 885   cream cheese    citrus fruit            0.088507            0.185480
# 884    citrus fruit  cream cheese             0.185480            0.088507
#
# ...

# %%
def suggestitem1(k):
    suggestpro=[]
    lift=[]
    
    df= pd.DataFrame()
    #rules_eda = rules1[(rules1['confidence']>=0.1) &( rules1['zhang'] > 0)&(rules1['leverage'] >  0.01435 0.0079) ]
    rules1 = rules_eda[(rules_eda['lift']>1) &( rules_eda['zhang'] > 0)&(rules_eda['leverage'] >  0) ]
    
 
    #rules_eda=rules1[(rules1['confidence']>=0.090)&( rules1['zhang'] > 0)&(rules['leverage'] > 0.0081911) ] 
    suggestpro = rules1[rules1['antecedents']==k]['consequents']
    lift=rules1[rules1['antecedents']==k]['lift'].round(3)
    confidence=rules1[rules1['antecedents']==k]['confidence'].round(3)
    support=rules1[rules1['antecedents']==k]['support'].round(3)
    leverage=rules1[rules1['antecedents']==k]['leverage'].round(3)
    conviction=rules1[rules1['antecedents']==k]['conviction'].round(3)
    df['items'] = suggestpro 
    df['lift']= lift
    df['support']= support
    
   
    top_products2 = df.sort_values('lift', ascending =False).head(6)
    
    
    lift_products = top_products2[['items','lift' ]]
    
    lift_products['score_type']='lift'
    
    lift_products.columns =['items', 'score', 'score_type']  
   
    lift_products['antecedents']= k
    
   
    lift_products=lift_products[['antecedents', 'items', 'score', 'score_type']]
    
    itmlst=lift_products[lift_products['antecedents']==k]['items'].head(5).to_list()
    
    if len(itmlst)>1:
        return lift_products[lift_products['antecedents']==k]['items'].head(5)
    else:
        itmlst=list(set(itmlst))
        itm=', '.join(itmlst)
        file = k
    #print(" By lift measure item suggested for ", k, "are ")
        return itmlst
        
print(suggestitem1('newspapers'))
suggestitem1('butter')
# Out:
# 1748       specialty bar
# 1740         salty snack
# 1447                 ham
# 805              chicken
# 1532    hygiene articles
# Name: items, dtype: object
# 525          chicken
# 549        ice cream
# 573      salty snack
# 533    cream cheese
# 78              beef
# Name: items, dtype: object

# %%
def suggestitem(k):
   
    
    rules_eda = rules1[(rules1['lift']>1) &( rules1['zhang'] > 0)&(rules1['leverage'] >  0) ]
    if len(rules_eda[rules_eda['antecedents']==k])!=0: 
        dataf=rules_eda[rules_eda['antecedents']==k][['antecedents','consequents', 'lift', 'leverage','scorelftlvg']]
        dat= dataf[['antecedents','consequents', 'lift','scorelftlvg']]
        dat=dat.sort_values(['lift'], ascending=False)
        daf=dataf[['antecedents','consequents', 'leverage','scorelftlvg']]
        daf=daf.sort_values(['leverage'], ascending=False)
        da=dataf[['antecedents','consequents', 'scorelftlvg']]
        da=da.sort_values(['scorelftlvg'], ascending=False)
        its=(da['consequents'].head(5)).to_list()
        print(its)
        if(collections.Counter(daf)==collections.Counter(dat)):
            itmlst=(daf['consequents'].head(5)).to_list()
            score=(daf['scorelftlvg'].head(5)).to_list()
        else:    
    
            itmlst=(daf['consequents'].head(3)).to_list()+(dat['consequents'].head(3)).to_list()
            itmlst=list(set(itmlst))
            score=[]
            for itm in itmlst:
                k =daf[daf['consequents']==itm]['scorelftlvg']
                score.append(k)
        itmlst=list(set(itmlst))
        itm=', '.join(itmlst)
    return itmlst
suggestitem('butter')
# Out:
# ['chicken', 'ice cream', 'salty snack', 'cream cheese ', 'beef']
# ['whole milk',
#  'chicken',
#  'yogurt',
#  'ice cream',
#  'salty snack',
#  'other vegetables']

# %%
def suggestitem(k):
   
    df=pd.DataFrame()
    rules_eda = rules1[(rules1['lift']>1) &( rules1['zhang'] > 0)&(rules1['leverage'] >  0) ]
    if len(rules_eda[rules_eda['antecedents']==k])!=0: 
        dataf=rules_eda[rules_eda['antecedents']==k][['antecedents','consequents', 'lift', 'leverage','scorelftlvg']]
        dat= dataf[['antecedents','consequents', 'lift','scorelftlvg']]
        dat=dat.sort_values(['lift'], ascending=False)
        daf=dataf[['antecedents','consequents', 'leverage','scorelftlvg']]
        daf=daf.sort_values(['leverage'], ascending=False)
        da=dataf[['antecedents','consequents', 'scorelftlvg']]
        da=da.sort_values(['scorelftlvg'], ascending=False)
        its=(da['consequents'].head(5)).to_list()        
        itmlst=(daf['consequents'].head(3)).to_list()+(dat['consequents'].head(3)).to_list()
        itmlst=list(set(itmlst))
        score=[]
        for itm in itmlst:
            f =daf[daf['consequents']==itm]['scorelftlvg'].item()
            score.append(f)
                
        frames=[itmlst, score]
        df['nextitem']=itmlst
        df['Score']= score
        #itm=', '.join(itmlst)   
        for i in range(len(df)):
            print(k, "is frequently bought with ",itmlst[i], " with score ","{:.2f}".format(score[i]) )
           
suggestitem('sugar')
# Out:
# sugar is frequently bought with  whole milk  with score  61.48
# sugar is frequently bought with  bottled water  with score  71.31
# sugar is frequently bought with  sausage  with score  75.90
# sugar is frequently bought with  canned beer  with score  74.45
# sugar is frequently bought with  fruit/vegetable juice  with score  74.95

# %%
grp1= ['coffee', 'frozen vegetables', 'chicken', 'white bread',
       'cream cheese ', 'chocolate', 'dessert', 'napkins', 'berries',
       'hamburger meat', 'UHT-milk', 'onions', 'salty snack', 'waffles',
       'long life bakery product', 'sugar', 'butter milk', 'ham', 'meat']
itmlst=[]
for i in range(len( grp1)):
       
    itmlst= suggestitem( grp1[i])
    #print(itmlst)
    
    #print(itmlst)
    #itm =', '.join(itmlst)
    #itm=', '.join(suggprod)
    
    
    
    #print("### These items can be frequently bought", itm, "with", grp1[i] )
# Out:
# coffee is frequently bought with  soda  with score  60.16
# coffee is frequently bought with  UHT-milk  with score  71.28
# coffee is frequently bought with  domestic eggs  with score  69.02
# coffee is frequently bought with  misc. beverages  with score  73.93
# coffee is frequently bought with  other vegetables  with score  57.20
# frozen vegetables is frequently bought with  whole milk  with score  59.06
# frozen vegetables is frequently bought with  UHT-milk  with score  70.22
# frozen vegetables is frequently bought with  napkins  with score  72.43
# frozen vegetables is frequently bought with  canned beer  with score  71.48
# frozen vegetables is frequently bought with  other vegetables  with score  59.43
# chicken is frequently bought with  butter  with score  74.94
# chicken is frequently bought with  fruit/vegetable juice  with score  72.77
# chicken is frequently bought with  waffles  with score  85.27
# chicken is frequently bought with  rolls/buns  with score  60.55
# ...

# %%
def suggestitem(k):
   
    
    rules1 = rules_eda[(rules_eda['lift']>1) &( rules_eda['zhang'] > 0)&(rules_eda['leverage'] >  0) ]
    if len(rules1[rules1['antecedents']==k])!=0: 
        dataf=rules1[rules1['antecedents']==k][['antecedents','consequents', 'confidence', 'conviction']]
        dat= dataf[['antecedents','consequents', 'confidence']]
        daf=dataf[['antecedents','consequents', 'conviction']]
        if(collections.Counter(daf)==collections.Counter(dat)):
            itmlst=(daf['consequents'].head(5)).to_list()
        else:    
    
            itmlst=(daf['consequents'].head(5)).to_list()+(dat['consequents'].head(5)).to_list()
    
        itmlst=list(set(itmlst))
        itm=', '.join(itmlst)
    return itmlst
        
        
#suggestitem('rolls/buns')
        
        
print(suggestitem('dessert'))
# Out:
# ['brown bread', 'bottled water', 'bottled beer', 'canned beer', 'butter']

# %%
df=pd.DataFrame()
itmlst=[]
def suggestitem(k):
    df=pd.DataFrame()
    rules_eda = rules1[(rules1['lift']>1) &( rules1['zhang'] > 0)&(rules1['leverage'] >  0) ]
    if len(rules_eda[rules_eda['antecedents']==k])!=0: 
        dataf=rules_eda[rules_eda['antecedents']==k][['antecedents','consequents', 'confidence', 'conviction','scoreconcnf']]
        dat= dataf[['antecedents','consequents', 'confidence','scoreconcnf']]
        dat=dat.sort_values(['confidence'], ascending=False)
        daf=dataf[['antecedents','consequents', 'conviction','scoreconcnf']]
        daf=daf.sort_values(['conviction'], ascending=False)
        da=dataf[['antecedents','consequents', 'scoreconcnf']]
        da=da.sort_values(['scoreconcnf'], ascending=False)
        its=(da['consequents'].head(5)).to_list()
        #print(its)
        itmlst=[]
        '''if(collections.Counter(daf)==collections.Counter(dat)):
            itmlst=(daf['consequents'].head(5)).to_list()
            print(itmlst)
            score=(daf['scoreconcnf'].head(5)).to_list()
            frames=[itmlst, score]
            print(score)
            df['nextitem']=itmlst
            df['Score']= score
            #df=pd.DataFrame(frames, columns= ['nextboughtitem','score'])
            #df=pd.DataFrame(frames).T
            print(df)
            return df'''
            
          
    
        itmlst=(daf['consequents'].head(5)).to_list()+(dat['consequents'].head(5)).to_list()
        itmlst=list(set(itmlst))
        score=[]
        for itm in itmlst:
            f =daf[daf['consequents']==itm]['scoreconcnf'].item()
            score.append(f)
                
        frames=[itmlst, score]
        df['nextitem']=itmlst
        df['Score']= score
            #df=pd.DataFrame(frames, columns= ['nextboughtitem','score']).T
            
        #itm=', '.join(itmlst)
        #print(itmlst)
        #print(score)
        #print(df)
        for i in range(min(6,len(df))):
            print(k, "--> ",itmlst[i], " with score ","{:.2f}".format(score[i]) )
        #return df
            
suggestitem('sugar')
# Out:
# sugar -->  whole milk  with score  89.63
# sugar -->  soda  with score  76.76
# sugar -->  yogurt  with score  68.60
# sugar -->  bottled water  with score  71.62
# sugar -->  sausage  with score  73.21
# sugar -->  rolls/buns  with score  75.97

# %%
itmlst=[]
dataf=pd.DataFrame()
grp= ['whole milk', 'other vegetables', 'rolls/buns', 'soda', 'yogurt',
       'root vegetables', 'tropical fruit', 'bottled water', 'sausage',
       'citrus fruit', 'pastry', 'pip fruit', 'shopping bags', 'canned beer',
       'bottled beer', 'newspapers', 'frankfurter', 'brown bread', 'pork', 'domestic eggs',
       'butter', 'fruit/vegetable juice', 'beef', 'curd', 'margarine',
       'coffee', 'frozen vegetables', 'chicken', 'white bread',
       'cream cheese ', 'chocolate', 'dessert', 'napkins', 'berries',
       'hamburger meat', 'UHT-milk', 'onions', 'salty snack', 'waffles',
       'long life bakery product', 'sugar', 'butter milk', 'ham', 'meat',
       'frozen meals', 'beverages', 'specialty chocolate', 'misc. beverages',
       'ice cream', 'oil', 'grapes', 'hard cheese', 'candy', 'sliced cheese',
       'specialty bar', 'hygiene articles', 'chewing gum', 'cat food',
       'white wine', 'herbs', 'red/blush wine', 'processed cheese',
       'soft cheese', 'flour', 'semi-finished bread', 'dishes',
       'pickled vegetables', 'detergent', 'packaged fruit/vegetables',
       'baking powder', 'pasta', 'pot plants', 'canned fish',
       'seasonal products', 'liquor', 'frozen fish', 'spread cheese',
       'condensed milk', 'cake bar', 'frozen dessert', 'mustard', 'salt',
       'pet care', 'canned vegetables',  'dog food' ]
itmlst=[]
for i in range(len( grp)):
       
    itmlst= suggestitem( grp[i])
    #print(itmlst)
    
    #print(itmlst)
    #itm =', '.join(itmlst)
    #itm=', '.join(suggprod)
    
    
    
    #print("### These items can be frequently bought", itm, "with", grp[i] )
# Out:
# whole milk -->  soda  with score  67.70
# whole milk -->  shopping bags  with score  61.90
# whole milk -->  yogurt  with score  69.84
# whole milk -->  bottled water  with score  64.35
# whole milk -->  tropical fruit  with score  64.08
# whole milk -->  other vegetables  with score  74.41
# other vegetables -->  whole milk  with score  80.49
# other vegetables -->  soda  with score  67.69
# other vegetables -->  yogurt  with score  68.66
# other vegetables -->  bottled water  with score  64.84
# other vegetables -->  sausage  with score  65.02
# other vegetables -->  root vegetables  with score  63.79
# rolls/buns -->  whole milk  with score  80.89
# rolls/buns -->  soda  with score  69.35
# rolls/buns -->  yogurt  with score  68.52
# rolls/buns -->  root vegetables  with score  64.95
# rolls/buns -->  other vegetables  with score  74.69
# soda -->  whole milk  with score  76.40
# soda -->  shopping bags  with score  62.70
# soda -->  yogurt  with score  67.58
# ...

# %%
for i in range(len( grp)):
       
    itmlst= suggestitem( grp[i])
    #print(itmlst)
    
    #print(itmlst)
    itm =', '.join(itmlst)
    #itm=', '.join(suggprod)
    
    
    
    
    print("### If you purchase these items ",', '.join(itmlst[:3]), ",  Get 10% additional discount on  total price")
    print("### If you purchase these items ",', '.join(itmlst), ",  Get 20% additional discount on  total price")
# Out:
# whole milk -->  soda  with score  67.70
# whole milk -->  shopping bags  with score  61.90
# whole milk -->  yogurt  with score  69.84
# whole milk -->  bottled water  with score  64.35
# whole milk -->  tropical fruit  with score  64.08
# whole milk -->  other vegetables  with score  74.41
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/1843469513.py in <module>
#       5
#       6     #print(itmlst)
# ----> 7     itm =', '.join(itmlst)
#       8     #itm=', '.join(suggprod)
#       9
#
# TypeError: can only join an iterable

# %%
itm =['roll products ', 'turkey',
       'photo/film', 'mayonnaise', 'cling film/bags', 'frozen potato products', 'specialty cheese', 'flower (seeds)',
       'sweet spreads', 'dog food', 'liquor (appetizer)', 'candles',
       'finished products', 'instant coffee', 'zwieback',
       'Instant food products', 'chocolate marshmallow', 'vinegar',
       'liver loaf', 'rice', 'popcorn', 'soups', 'sparkling wine',
       'curd cheese', 'house keeping products', 'sauces', 'cereals',
       'softener', 'spices', 'female sanitary products', 'brandy',
       'male cosmetics', 'meat spreads', 'jam', 'dental care', 'nuts/prunes',
       'ketchup', 'rum', 'cleaner', 'kitchen towels', 'specialty fat',
       'artif. sweetener', 'light bulbs', 'fish', 'tea', 'snack products',
       'potato products', 'abrasive cleaner', 'tidbits', 'organic sausage',
       'nut snack', 'syrup', 'canned fruit', 'skin care', 'soap', 'prosecco',
       'bathroom cleaner', 'cookware', 'pudding powder',
       'flower soil/fertilizer', 'cocoa drinks', 'ready soups',
       'cooking chocolate', 'honey', 'cream', 'frozen fruits',
       'specialty vegetables', 'organic products', 'liqueur', 'hair spray',
       'decalcifier', 'whisky', 'salad dressing', 'toilet cleaner',
       'rubbing alcohol', 'frozen chicken', 'make up remover', 'bags',
       'baby cosmetics', 'preservation products', 'kitchen utensil'  ]

# %%
rules_eda[rules_eda['antecedents']=='preservation products']
